# %% [markdown]
# <a href="https://colab.research.google.com/github/chiara-camilla-rambaldi-migliore/FormalMethods/blob/main/Lab_02/Pysmt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pysmt
# Out:
# Collecting pysmt
#   Downloading PySMT-0.9.0-py2.py3-none-any.whl (317 kB)
#      |████████████████████████████████| 317 kB 5.2 MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from pysmt) (1.15.0)
# Installing collected packages: pysmt
# Successfully installed pysmt-0.9.0

# %%
# !apt update
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Ign:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Ign:3 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Get:5 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:6 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Hit:7 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:8 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:9 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:10 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ Packages [80.4 kB]
# Hit:11 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Get:13 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Get:14 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease [15.9 kB]
# Hit:16 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Get:17 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main Sources [1,827 kB]
# Get:18 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [2,628 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [2,257 kB]
# Get:20 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [1,479 kB]
# Get:21 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 Packages [936 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [3,067 kB]
# Get:23 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic/main amd64 Packages [45.2 kB]
# Fetched 12.6 MB in 4s (3,057 kB/s)
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# 63 packages can be upgraded. Run 'apt list --upgradable' to see them.

# %%
# !apt-get install libgmp3-dev
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   libgmp-dev libgmpxx4ldbl
# Suggested packages:
#   gmp-doc libgmp10-doc libmpfr-dev
# The following NEW packages will be installed:
#   libgmp-dev libgmp3-dev libgmpxx4ldbl
# 0 upgraded, 3 newly installed, 0 to remove and 63 not upgraded.
# Need to get 327 kB of archives.
# After this operation, 1,689 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgmpxx4ldbl amd64 2:6.1.2+dfsg-2 [8,964 B]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgmp-dev amd64 2:6.1.2+dfsg-2 [316 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgmp3-dev amd64 2:6.1.2+dfsg-2 [1,996 B]
# Fetched 327 kB in 1s (410 kB/s)
# Selecting previously unselected package libgmpxx4ldbl:amd64.
# (Reading database ... 155335 files and directories currently installed.)
# Preparing to unpack .../libgmpxx4ldbl_2%3a6.1.2+dfsg-2_amd64.deb ...
# Unpacking libgmpxx4ldbl:amd64 (2:6.1.2+dfsg-2) ...
# Selecting previously unselected package libgmp-dev:amd64.
# Preparing to unpack .../libgmp-dev_2%3a6.1.2+dfsg-2_amd64.deb ...
# Unpacking libgmp-dev:amd64 (2:6.1.2+dfsg-2) ...
# Selecting previously unselected package libgmp3-dev.
# Preparing to unpack .../libgmp3-dev_2%3a6.1.2+dfsg-2_amd64.deb ...
# Unpacking libgmp3-dev (2:6.1.2+dfsg-2) ...
# Setting up libgmpxx4ldbl:amd64 (2:6.1.2+dfsg-2) ...
# Setting up libgmp-dev:amd64 (2:6.1.2+dfsg-2) ...
# Setting up libgmp3-dev (2:6.1.2+dfsg-2) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.3) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link

# %%
# !pysmt-install --msat
# Out:
# This script allows you to install the solvers supported by pySMT.
#
# By executing this script, you confirm that you have read and agreed
# with the licenses of each solver.
#
# Notice: the installation process might require building tools
#         (e.g., make and gcc).
#
# Continue? [Y]es/[N]o: Y
# Downloading: /root/.smt_solvers/msat/mathsat-5.6.1-linux-x86_64.tar.gz Bytes: 12177865
# 100.0%
# running build_ext
# building '_mathsat' extension
# creating build
# creating build/temp.linux-x86_64-3.7
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fdebug-prefix-map=/build/python3.7-pX47U3/python3.7-3.7.12=. -fstack-protector-strong -Wformat -Werror=format-security -g -fdebug-prefix-map=/build/python3.7-pX47U3/python3.7-3.7.12=. -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -DSWIG=1 -I../include -I/usr/include/python3.7m -c mathsat_python_wrap.c -o build/temp.linux-x86_64-3.7/mathsat_python_wrap.o
# mathsat_python_wrap.c: In function ‘call_visit_python_callable’:
# mathsat_python_wrap.c:3509:16: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#      if (retval == -1) {
#                 ^~
# mathsat_python_wrap.c: In function ‘_wrap__msat_is_bv_type’:
# mathsat_python_wrap.c:6331:11: warning: unused variable ‘out_width’ [-Wunused-variable]
#    size_t *out_width ;
#            ^~~~~~~~~
# mathsat_python_wrap.c:6330:13: warning: unused variable ‘tp’ [-Wunused-variable]
#    msat_type tp ;
#              ^~
# mathsat_python_wrap.c:6329:12: warning: unused variable ‘env’ [-Wunused-variable]
#    msat_env env ;
#             ^~~
# mathsat_python_wrap.c: In function ‘_wrap__msat_is_array_type’:
# mathsat_python_wrap.c:6394:14: warning: unused variable ‘out_etp’ [-Wunused-variable]
#    msat_type *out_etp ;
#               ^~~~~~~
# mathsat_python_wrap.c:6393:14: warning: unused variable ‘out_itp’ [-Wunused-variable]
#    msat_type *out_itp ;
#               ^~~~~~~
# mathsat_python_wrap.c:6392:13: warning: unused variable ‘tp’ [-Wunused-variable]
#    msat_type tp ;
#              ^~
# mathsat_python_wrap.c:6391:12: warning: unused variable ‘env’ [-Wunused-variable]
#    msat_env env ;
#             ^~~
# mathsat_python_wrap.c: In function ‘_wrap__msat_is_fp_type’:
# mathsat_python_wrap.c:6473:11: warning: unused variable ‘out_mant_width’ [-Wunused-variable]
#    size_t *out_mant_width ;
#            ^~~~~~~~~~~~~~
# mathsat_python_wrap.c:6472:11: warning: unused variable ‘out_exp_width’ [-Wunused-variable]
#    size_t *out_exp_width ;
#            ^~~~~~~~~~~~~
# mathsat_python_wrap.c:6471:13: warning: unused variable ‘tp’ [-Wunused-variable]
#    msat_type tp ;
#              ^~
# mathsat_python_wrap.c:6470:12: warning: unused variable ‘env’ [-Wunused-variable]
#    msat_env env ;
#             ^~~
# mathsat_python_wrap.c: In function ‘_wrap_msat_type_repr’:
# mathsat_python_wrap.c:6621:13: warning: unused variable ‘t’ [-Wunused-variable]
#    msat_type t ;
#              ^
# mathsat_python_wrap.c: In function ‘_wrap__msat_term_to_number’:
# mathsat_python_wrap.c:12382:7: warning: variable ‘result’ set but not used [-Wunused-but-set-variable]
#    int result;
#        ^~~~~~
# mathsat_python_wrap.c:12381:9: warning: unused variable ‘out’ [-Wunused-variable]
#    mpq_t out ;
#          ^~~
# mathsat_python_wrap.c:12380:13: warning: unused variable ‘t’ [-Wunused-variable]
#    msat_term t ;
#              ^
# mathsat_python_wrap.c:12379:12: warning: unused variable ‘e’ [-Wunused-variable]
#    msat_env e ;
#             ^
# mathsat_python_wrap.c: In function ‘_wrap__msat_term_is_int_modular_congruence’:
# mathsat_python_wrap.c:12962:9: warning: unused variable ‘out_mod’ [-Wunused-variable]
#    mpz_t out_mod ;
#          ^~~~~~~
# mathsat_python_wrap.c:12961:13: warning: unused variable ‘t’ [-Wunused-variable]
#    msat_term t ;
#              ^
# mathsat_python_wrap.c:12960:12: warning: unused variable ‘e’ [-Wunused-variable]
#    msat_env e ;
#             ^
# mathsat_python_wrap.c: In function ‘_wrap__msat_term_is_bv_extract’:
# mathsat_python_wrap.c:13503:11: warning: unused variable ‘out_lsb’ [-Wunused-variable]
#    size_t *out_lsb ;
#            ^~~~~~~
# mathsat_python_wrap.c:13502:11: warning: unused variable ‘out_msb’ [-Wunused-variable]
#    size_t *out_msb ;
#            ^~~~~~~
# mathsat_python_wrap.c:13501:13: warning: unused variable ‘t’ [-Wunused-variable]
#    msat_term t ;
#              ^
# mathsat_python_wrap.c:13500:12: warning: unused variable ‘e’ [-Wunused-variable]
#    msat_env e ;
#             ^
# mathsat_python_wrap.c: In function ‘_wrap__msat_term_is_bv_zext’:
# mathsat_python_wrap.c:14390:11: warning: unused variable ‘out_amount’ [-Wunused-variable]
#    size_t *out_amount ;
#            ^~~~~~~~~~
# mathsat_python_wrap.c:14389:13: warning: unused variable ‘t’ [-Wunused-variable]
#    msat_term t ;
#              ^
# mathsat_python_wrap.c:14388:12: warning: unused variable ‘e’ [-Wunused-variable]
#    msat_env e ;
#             ^
# mathsat_python_wrap.c: In function ‘_wrap__msat_term_is_bv_sext’:
# mathsat_python_wrap.c:14450:11: warning: unused variable ‘out_amount’ [-Wunused-variable]
#    size_t *out_amount ;
#            ^~~~~~~~~~
# mathsat_python_wrap.c:14449:13: warning: unused variable ‘t’ [-Wunused-variable]
#    msat_term t ;
#              ^
# mathsat_python_wrap.c:14448:12: warning: unused variable ‘e’ [-Wunused-variable]
#    msat_env e ;
#             ^
# mathsat_python_wrap.c: In function ‘_wrap__msat_term_is_bv_rol’:
# mathsat_python_wrap.c:14510:11: warning: unused variable ‘out_amount’ [-Wunused-variable]
#    size_t *out_amount ;
#            ^~~~~~~~~~
# mathsat_python_wrap.c:14509:13: warning: unused variable ‘t’ [-Wunused-variable]
#    msat_term t ;
#              ^
# mathsat_python_wrap.c:14508:12: warning: unused variable ‘e’ [-Wunused-variable]
#    msat_env e ;
#             ^
# mathsat_python_wrap.c: In function ‘_wrap__msat_term_is_bv_ror’:
# mathsat_python_wrap.c:14570:11: warning: unused variable ‘out_amount’ [-Wunused-variable]
#    size_t *out_amount ;
#            ^~~~~~~~~~
# mathsat_python_wrap.c:14569:13: warning: unused variable ‘t’ [-Wunused-variable]
#    msat_term t ;
#              ^
# mathsat_python_wrap.c:14568:12: warning: unused variable ‘e’ [-Wunused-variable]
#    msat_env e ;
#             ^
# mathsat_python_wrap.c: In function ‘_wrap_msat_decl_get_name’:
# mathsat_python_wrap.c:16673:13: warning: unused variable ‘d’ [-Wunused-variable]
#    msat_decl d ;
#              ^
# mathsat_python_wrap.c: In function ‘_wrap_msat_decl_repr’:
# mathsat_python_wrap.c:16710:13: warning: unused variable ‘d’ [-Wunused-variable]
#    msat_decl d ;
#              ^
# mathsat_python_wrap.c: In function ‘_wrap_msat_term_repr’:
# mathsat_python_wrap.c:16747:13: warning: unused variable ‘t’ [-Wunused-variable]
#    msat_term t ;
#              ^
# mathsat_python_wrap.c: In function ‘_wrap_msat_to_smtlib1’:
# mathsat_python_wrap.c:16909:13: warning: unused variable ‘term’ [-Wunused-variable]
#    msat_term term ;
#              ^~~~
# mathsat_python_wrap.c:16908:12: warning: unused variable ‘e’ [-Wunused-variable]
#    msat_env e ;
#             ^
# mathsat_python_wrap.c: In function ‘_wrap_msat_to_smtlib2’:
# mathsat_python_wrap.c:16962:13: warning: unused variable ‘term’ [-Wunused-variable]
#    msat_term term ;
#              ^~~~
# mathsat_python_wrap.c:16961:12: warning: unused variable ‘e’ [-Wunused-variable]
#    msat_env e ;
#             ^
# mathsat_python_wrap.c: In function ‘_wrap__msat_named_list_from_smtlib2’:
# mathsat_python_wrap.c:17132:15: warning: unused variable ‘out_terms’ [-Wunused-variable]
#    msat_term **out_terms ;
#                ^~~~~~~~~
# mathsat_python_wrap.c:17131:11: warning: unused variable ‘out_names’ [-Wunused-variable]
#    char ***out_names ;
#            ^~~~~~~~~
# mathsat_python_wrap.c:17130:11: warning: unused variable ‘out_n’ [-Wunused-variable]
#    size_t *out_n ;
#            ^~~~~
# mathsat_python_wrap.c:17129:15: warning: unused variable ‘data’ [-Wunused-variable]
#    char const *data ;
#                ^~~~
# mathsat_python_wrap.c:17128:12: warning: unused variable ‘e’ [-Wunused-variable]
#    msat_env e ;
#             ^
# mathsat_python_wrap.c: In function ‘_wrap__msat_annotated_list_from_smtlib2’:
# mathsat_python_wrap.c:17330:11: warning: unused variable ‘out_annots’ [-Wunused-variable]
#    char ***out_annots ;
#            ^~~~~~~~~~
# mathsat_python_wrap.c:17329:15: warning: unused variable ‘out_terms’ [-Wunused-variable]
#    msat_term **out_terms ;
#                ^~~~~~~~~
# mathsat_python_wrap.c:17328:11: warning: unused variable ‘out_n’ [-Wunused-variable]
#    size_t *out_n ;
#            ^~~~~
# mathsat_python_wrap.c:17327:15: warning: unused variable ‘data’ [-Wunused-variable]
#    char const *data ;
#                ^~~~
# mathsat_python_wrap.c:17326:12: warning: unused variable ‘e’ [-Wunused-variable]
#    msat_env e ;
#             ^
# mathsat_python_wrap.c: In function ‘_wrap__msat_get_asserted_formulas’:
# mathsat_python_wrap.c:18030:11: warning: unused variable ‘num_asserted’ [-Wunused-variable]
#    size_t *num_asserted ;
#            ^~~~~~~~~~~~
# mathsat_python_wrap.c:18029:12: warning: unused variable ‘e’ [-Wunused-variable]
#    msat_env e ;
#             ^
# mathsat_python_wrap.c: In function ‘_wrap__msat_get_theory_lemmas’:
# mathsat_python_wrap.c:18084:11: warning: unused variable ‘num_tlemmas’ [-Wunused-variable]
#    size_t *num_tlemmas ;
#            ^~~~~~~~~~~
# mathsat_python_wrap.c:18083:12: warning: unused variable ‘e’ [-Wunused-variable]
#    msat_env e ;
#             ^
# mathsat_python_wrap.c: In function ‘_wrap__msat_get_unsat_core’:
# mathsat_python_wrap.c:18590:11: warning: unused variable ‘core_size’ [-Wunused-variable]
#    size_t *core_size ;
#            ^~~~~~~~~
# mathsat_python_wrap.c:18589:12: warning: unused variable ‘e’ [-Wunused-variable]
#    msat_env e ;
#             ^
# mathsat_python_wrap.c: In function ‘_wrap__msat_get_unsat_assumptions’:
# mathsat_python_wrap.c:18698:11: warning: unused variable ‘assumps_size’ [-Wunused-variable]
#    size_t *assumps_size ;
#            ^~~~~~~~~~~~
# mathsat_python_wrap.c:18697:12: warning: unused variable ‘e’ [-Wunused-variable]
#    msat_env e ;
#             ^
# mathsat_python_wrap.c: In function ‘_wrap_msat_make_uf’:
# mathsat_python_wrap.c:7926:8: warning: ‘arg3’ may be used uninitialized in this function [-Wmaybe-uninitialized]
#      if (arg3) free(arg3);
#         ^
# mathsat_python_wrap.c: In function ‘_wrap_msat_existentially_quantify’:
# mathsat_python_wrap.c:11890:15: warning: ‘arg3’ may be used uninitialized in this function [-Wmaybe-uninitialized]
#      if (arg3) free(arg3);
#                ^~~~~~~~~~
# mathsat_python_wrap.c: In function ‘_wrap_msat_make_term’:
# mathsat_python_wrap.c:11967:8: warning: ‘arg3’ may be used uninitialized in this function [-Wmaybe-uninitialized]
#      if (arg3) free(arg3);
#         ^
# creating build/lib.linux-x86_64-3.7
# x86_64-linux-gnu-g++ -pthread -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -Wl,-z,relro -Wl,-Bsymbolic-functions -Wl,-z,relro -g -fdebug-prefix-map=/build/python3.7-pX47U3/python3.7-3.7.12=. -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 build/temp.linux-x86_64-3.7/mathsat_python_wrap.o -L../lib -Wl,--enable-new-dtags,-R$ORIGIN -lmathsat -lgmpxx -lgmp -o build/lib.linux-x86_64-3.7/_mathsat.cpython-37m-x86_64-linux-gnu.so

# %%
# !pysmt-install --check
# Out:
# Installed Solvers:
#   msat      True (5.6.1)
#   cvc4      False (None)              Not in Python's path!
#   z3        False (None)              Not in Python's path!
#   yices     False (None)              Not in Python's path!
#   btor      False (None)              Not in Python's path!
#   picosat   False (None)              Not in Python's path!
#   bdd       False (None)              Not in Python's path!
#
# Solvers: msat
# Quantifier Eliminators: msat_fm, msat_lw, shannon, selfsub
# UNSAT-Cores: msat
# Interpolators: msat

# %%
from pysmt.shortcuts import *

day_company = {"dc{}{}".format(i,j): Symbol("dc{}{}".format(i,j), BOOL) for i in range(0,4) for j in "alsi"}
day_role = {"dr{}{}".format(i,j): Symbol("dr{}{}".format(i,j), BOOL) for i in range(0,4) for j in "cgrm"}

var = {**day_company, **day_role}

final_answer = ["20th: ", "21st: ", "22nd: ", "23rd: "]

msat = Solver()

# The Alpha Plus interview is 2 days before the meeting for the copywriter position.
msat.add_assertion(Or(And(var["dc0a"], var["dr2c"]), And(var["dc1a"], var["dr3c"])))

#The meeting for the graphic design position is some time after the Sancode interview
msat.add_assertion(And(Not(var["dr0g"]), Not(var["dc3s"]), Not(And(var["dr1g"], var["dc2s"])) )) 

# Of the interview for the sales rep position and the Laneplex interview, one is on August 23rd and the other is on August 20th.
msat.add_assertion(Or(And(var["dc0l"],var["dr3r"]), And(var["dc3l"],var["dr0r"])))

# The Streeter Inc. interview is 2 days after the Alpha Plus interview.
msat.add_assertion(Or(And(var["dc2i"], var["dc0a"]), And(var["dc3i"], var["dc1a"])))

# On the 23rd there is no interview for social media roles
msat.add_assertion(Not(var["dr3m"]))

# Each day must be associated to exactly one company
for i in range(0,4):
	msat.add_assertion(ExactlyOne([var["dc{}{}".format(i, j)] for j in "alsi"]))

# Each day must be associated to exactly one role
for i in range(0,4):
	msat.add_assertion(ExactlyOne([var["dr{}{}".format(i, j)] for j in "cgrm"]))	

# Each company must be associated to exactly one day
for j in "alsi":
	msat.add_assertion(ExactlyOne([var["dc{}{}".format(i, j)] for i in range(0,4)]))

# Each role must be associated to exactly one day
for j in "cgrm":
	msat.add_assertion(ExactlyOne([var["dr{}{}".format(i, j)] for i in range(0,4)]))


# Optional (but strongly suggested): prettify the results
companies = {"a": "Alpha Plus", "l":"Laneplex", "s": "Sancode", "i": "Streeter Inc."}
roles = {"c": "copywriter", 'g':'graphic design', 'r':'sales rep', 'm': 'social media'}

res = msat.solve()
if res:
	sat_model = {el[0].symbol_name():el[1] for el in msat.get_model()}
	for i in range(0,4):
		for j in "alsi":
			if sat_model["dc{}{}".format(i,j)] == Bool(True):
				final_answer[i] = final_answer[i] + companies[j] + " - "
		for j in "cgrm":
			if sat_model["dr{}{}".format(i,j)] == Bool(True):
				final_answer[i] = final_answer[i] + roles[j]
	print("\n".join(final_answer))
else:
	print("UNSAT")

# OPTIONAL: is the solution unique?
msat.add_assertion(Not(And(var["dc0a"], var["dc1s"], var["dc2i"], var["dc3l"], var["dr0r"], var["dr1m"], var["dr2c"], var["dr3g"])))

final_answer = ["20th: ", "21st: ", "22nd: ", "23rd: "]

res = msat.solve()
if res:
	sat_model = {el[0].symbol_name():el[1] for el in msat.get_model()}
	for i in range(0,4):
		for j in "alsi":
			if sat_model["dc{}{}".format(i,j)] == Bool(True):
				final_answer[i] = final_answer[i] + companies[j] + " - "
		for j in "cgrm":
			if sat_model["dr{}{}".format(i,j)] == Bool(True):
				final_answer[i] = final_answer[i] + roles[j]
	print("\n".join(final_answer))
else:
	print("UNSAT")
# Out:
# /usr/local/lib/python3.7/dist-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /usr/local/lib/python3.7/dist-packages/pysmt/smtlib/parser/parser.py
#   tree = Parsing.p_module(s, pxd, full_module_name)
# 20th: Alpha Plus - sales rep
# 21st: Sancode - social media
# 22nd: Streeter Inc. - copywriter
# 23rd: Laneplex - graphic design
# UNSAT
